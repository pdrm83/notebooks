# %% [markdown]
# Given a list of daily temperatures T, return a list such that, for each day in the input, tells you how many days you would have to wait until a warmer temperature. If there is no future day for which this is possible, put 0 instead.
#
# For example, given the list of temperatures T = [73, 74, 75, 71, 69, 72, 76, 73], your output should be [1, 1, 4, 2, 1, 1, 0, 0].
#
# Note: The length of temperatures will be in the range [1, 30000]. Each temperature will be an integer in the range [30, 100].

# %%
from queue import Queue  

def count_day(temperature_list):
  temperature = Queue()
  max_val = temperature_list[0]
  result = [0 for i in range(len(temperature_list))]
  temperature.put(temperature_list[0])
  counter = 0

  for i in range(len(temperature_list)-1):
    print(counter)
    print(temperature.queue[0])
    if temperature.queue[0] < temperature_list[i+1]:
      temperature.put(temperature_list[i+1])
      counter += 1
      result[i] = counter
      max_val = max(max_val, temperature_list[i+1] )
    else:
      counter -= 1
      temperature.get()

  return result

if __name__ == "__main__":
  temperature_list = [32, 45, 50, 30, 35, 40, 34]
  desired_output = [1, 1, 0, 1, 1, 1, 0]
  result = count_day(temperature_list)
  print(result)
# Out:
# 0
# 32
# 1
# 32
# 2
# 32
# 1
# 45
# 0
# 50
# -1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-a5c1510ed19e> in <module>()
#      25   temperature_list = [32, 45, 50, 30, 35, 40, 34]
#      26   desired_output = [1, 1, 0, 1, 1, 1, 0]
# ---> 27   result = count_day(temperature_list)
#      28   print(result)
#
# <ipython-input-19-a5c1510ed19e> in count_day(temperature_list)
#      10   for i in range(len(temperature_list)-1):
#      11     print(counter)
# ---> 12     print(temperature.queue[0])
#      13     if temperature.queue[0] < temperature_list[i+1]:
#      14       temperature.put(temperature_list[i+1])
#
# IndexError: deque index out of range
