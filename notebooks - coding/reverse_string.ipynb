# %%
def reverse(string):
  pass

# %%
if __name__ == "__main__":
  x = 'This is the best'
  result = 'best the is This'
  print("-".join(reversed(x.split())))
  print("*".join(x.split()[::-1]))
# Out:
# best-the-is-This
# best*the*is*This
